# %% [raw]
# Amazon works on this algorithm..It is unsupervised algorithm ..In this k times mean is taken...

# %% [raw]
# k={2,3,4,10,11,12,20,25,30}
# suppose we have to form 2 clusters
# Three steps are there:select two random numbers and based on that form 2 cluster..

# %%
suppose we take two numbers as 4 and 10 then two clusters formed will be

k1={2,3,4} k2={10,11,12,13,20,25,30}

# %%
Now again form two clusters with mean of the above clusters
means are m1=3 m2=18
so again k1={2,3,4,10} k2={11,12,13,20,25,30}

# %% [raw]
# repeat it till the time you get the same mean...

# %% [markdown]
# # DECISION TREE EXPLANATION

# %%
from IPython.display import Image
img1=Image(filename='./images/Decision_Tree_1.png')
img1

# %% [raw]
# Information Gain
# The information gain is based on the decrease in entropy after a dataset is split on an attribute. Constructing a decision tree is all about finding attribute that returns the highest information gain (i.e., the most homogeneous branches).

# %% [raw]
# Entropy using the frequency table of one attribute:

# %%
from IPython.display import Image
img1=Image(filename='./images/Entropy_3.png')
img1

# %% [raw]
#  Entropy using the frequency table of two attributes:

# %%
from IPython.display import Image
img2=Image(filename='./images/Entropy_5.png')
img2

# %% [raw]
# Step 1: Calculate entropy of the target.

# %% [raw]
# The dataset is then split on the different attributes. The entropy for each branch is calculated. Then it is added proportionally, to get total entropy for the split. The resulting entropy is subtracted from the entropy before the split. The result is the Information Gain, or decrease in entropy.

# %%
from IPython.display import Image
img3=Image(filename='./images/Entropy_attributes.png')
img3

# %%
from IPython.display import Image
img4=Image(filename='./images/Entropy_gain.png')
img4

# %% [raw]
# Step 3: Choose attribute with the largest information gain as the decision node, divide the dataset by its branches and repeat the same process on every branch.
