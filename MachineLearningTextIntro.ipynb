# %% [markdown]
# # MACHINE LEARNING WITH TEXT

# %% [raw]
# Prerequisites:
#     1)LITTLE KNOWLEDGE OF VECTORS AND PROBABILITY
#     2)KNOWLEDGE OF ARCHITECTURE OF NEURAL NETWORK
#     3)KNOWLEDGE OF PYTHON
#     4)KNOWLEDGE OF NAIVE-BAYES ALGORITHM

# %% [markdown]
# # TOPIC 1: WORD EMBEDDINGS and WORD2VEC

# %%
from IPython.display import Image
Image(filename='images/Word-Vectors.png')

# %% [markdown]
# # TOPIC 2:BAG OF WORDS,TF-IDFN-GRAMS

# %%
from IPython.display import Image
Image(filename='images/bag_of_words.jpg')

# %% [markdown]
# # INTRO TO RECURRENCE NEURAL NETWORK

# %%
from IPython.display import Image
Image(filename='images/recurrence_neural_network.png')

# %% [markdown]
# # SEQUENCE TO SEQUENCE AND LSTM

# %%
from IPython.display import Image
Image(filename='images/seq_seq.jpg')

# %% [markdown]
# # NLP ,NLTK,GLOVE,SCAPY-NLP LIBRARIES TO USE

# %%
from IPython.display import Image
Image(filename='images/glove.jpg')

# %% [markdown]
# # WAYS TO MAKE CHATBOT

# %%
from IPython.display import Image
Image(filename='images/chatbot.jpg')
